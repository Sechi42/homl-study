# %% [markdown]
# # Chapter 6 Exercises: Ensemble Learning and Random Forests
#
# Use the cells below to write your answers. Exercises 1 to 7 are left as Markdown prompts, and Exercises 8 to 9 are prepared as Python cells for your code.

# %% [markdown]
# ## Exercise 1
# If you have trained five different models on the exact same training data, and they all achieve 95% precision, is there any chance that you can combine these models to get better results? If so, how? If not, why?
#
# **Answer:** Yes, if the three models get that accuracy it can combine it's respoinses and get a better perfomance on group because statistically each differt model predict different on each instances provoking tha't the mode or the mean (depends on the case) of each prediction can get a robust responses

# %% [markdown]
# ## Exercise 2
# What is the difference between hard and soft voting classifiers?
#
# **Answer:** The difference is that the hard voting focuses on the mode of the predictions of each model on the other hand we have that on the soft voting method, each model predict in probabilities, and is based on the boundary desicion of the models, they needs to be calibrated also

# %% [markdown]
# ## Exercise 3
# Is it possible to speed up training of a bagging ensemble by distributing it across multiple servers? What about pasting ensembles, boosting ensembles, random forests, or stacking ensembles?
#
# **Answer:** Yes, it´s possible because each machine can compute and distribute a model with different boostrap training data. Stacking, can be computed at the same, models on each machine, that can be communicate with the union model of outputs, pasting at the same can be computed on parallel, boosting is more complex because you need the errors before train the next desiciotree, randomforest can be computed parallel because you can train trees independetly

# %% [markdown]
# ## Exercise 4
# What is the benefit of out-of-bag evaluation?
#
# **Answer:** The benefit is on terms of cross validation computing, you can save a lot of time becaus you can use the rows that each model did't train it and creat an estimated accuracy without corss-validaition computing

# %% [markdown]
# ## Exercise 5
# What makes extra-trees ensembles more random than regular random forests? How can this extra randomness help? Are extra-trees classifiers slower or faster than regular random forests?
#
# **Answer:** What makes extra-trees more random is the system of ramdom cuts that make on the trushold charatetistics and has a better performance on terms of computing efficience

# %% [markdown]
# ## Exercise 6
# If your AdaBoost ensemble underfits the training data, which hyperparameters should you tweak, and how?
#
# **Answer:**

# %% [markdown]
# ## Exercise 7
# If your gradient boosting ensemble overfits the training set, should you increase or decrease the learning rate?
#
# **Answer:**

# %%
# Exercise 8
# Load the MNIST dataset, split it into train/validation/test sets,
# train several classifiers, and try to combine them with voting.
#
# Your code here.
pass

# %%
# Exercise 9
# Build a stacking ensemble using the validation predictions from the
# previous exercise, then compare it with a StackingClassifier.
#
# Your code here.
pass
